# %%
file = open('C://Users//User//Downloads//bitmex_data_1m.csv','r')
print(file.readline())
for i in range(100):
    file.readline()

file.readline()
# Out:
# timestamp,symbol,open,high,low,close,trades,volume,vwap,lastSize,turnover,homeNotional,foreignNotional
# '2015-09-25 13:41:00+00:00,XBTUSD,237.45,237.45,237.45,237.45,0,0,,,0,0.0,0.0\n'

# %%
import pandas as pd
df = pd.read_csv('C://Users//User//Downloads//bitmex_data_1m.csv', delimiter=',')

# %%
import datetime 
import time

#df의 timestamp 행을 Windowing 하기위해 int 형태로 바꾸는 함수
def convert_to_timestamp(row):
    return time.mktime(datetime.datetime.strptime(row, '%Y-%m-%d %H:%M:%S').timetuple())

#+00:00 를 없애고 KST 로 바꾸는 함수
def convert_gmt_to_kst(row):
    return str(datetime.datetime.strptime(row, '%Y-%m-%d %H:%M:%S+00:00')+datetime.timedelta(hours=9)-datetime.timedelta(minutes=1))

#timestamp int 형태를 string 형태의 yyy-MM-dd HH:mm:ss 로 바꾸기
def convert_timestamp_to_datetime_str(row):
    return str(datetime.datetime.fromtimestamp(row))
#time.mktime(datetime.datetime.strptime(df['timestamp'][0], '%Y-%m-%d %H:%M:%S+00:00').timetuple())

# %%
df
# Out:
#                          timestamp  symbol     open     high      low  \
# 0        2015-09-25 12:01:00+00:00  XBTUSD      NaN      NaN      NaN
# 1        2015-09-25 12:02:00+00:00  XBTUSD      NaN      NaN      NaN
# 2        2015-09-25 12:03:00+00:00  XBTUSD      NaN      NaN      NaN
# 3        2015-09-25 12:04:00+00:00  XBTUSD      NaN      NaN      NaN
# 4        2015-09-25 12:05:00+00:00  XBTUSD      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 4005552  2023-05-08 03:13:00+00:00  XBTUSD  28320.5  28328.5  28320.5
# 4005553  2023-05-08 03:14:00+00:00  XBTUSD  28328.5  28330.0  28329.5
# 4005554  2023-05-08 03:15:00+00:00  XBTUSD  28330.0  28329.5  28320.0
# 4005555  2023-05-08 03:16:00+00:00  XBTUSD  28320.0  28322.5  28289.5
# 4005556  2023-05-08 03:17:00+00:00  XBTUSD  28304.0  28314.0  28301.5
#
#            close  trades   volume      vwap  lastSize    turnover  \
# ...

# %%
cleaned_df = df.dropna()

# %%
cleaned_df
# Out:
#                          timestamp  symbol      open      high       low  \
# 34       2015-09-25 12:35:00+00:00  XBTUSD    239.99    239.99    239.99
# 37       2015-09-25 12:38:00+00:00  XBTUSD    239.99    237.43    237.43
# 38       2015-09-25 12:39:00+00:00  XBTUSD    237.43    237.41    237.39
# 42       2015-09-25 12:43:00+00:00  XBTUSD    237.39    237.49    237.37
# 45       2015-09-25 12:46:00+00:00  XBTUSD    237.49    237.46    237.46
# ...                            ...     ...       ...       ...       ...
# 4005552  2023-05-08 03:13:00+00:00  XBTUSD  28320.50  28328.50  28320.50
# 4005553  2023-05-08 03:14:00+00:00  XBTUSD  28328.50  28330.00  28329.50
# 4005554  2023-05-08 03:15:00+00:00  XBTUSD  28330.00  28329.50  28320.00
# 4005555  2023-05-08 03:16:00+00:00  XBTUSD  28320.00  28322.50  28289.50
# 4005556  2023-05-08 03:17:00+00:00  XBTUSD  28304.00  28314.00  28301.50
#
#             close  trades   volume      vwap  lastSize    turnover  \
# ...

# %%
y=cleaned_df[['timestamp','high','low','open','close']]

# %%
sample_y_df = y.iloc[-1000:]
sample_y_df['high_score']=0
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/2323228302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_y_df['high_score']=0

# %%
sample_y_df
# Out:
#                          timestamp     high      low     open    close  \
# 4004534  2023-05-07 10:15:00+00:00  28866.5  28864.5  28866.5  28864.5
# 4004535  2023-05-07 10:16:00+00:00  28878.0  28855.5  28864.5  28870.5
# 4004536  2023-05-07 10:17:00+00:00  28880.5  28870.5  28870.5  28877.5
# 4004537  2023-05-07 10:18:00+00:00  28876.5  28865.5  28877.5  28866.0
# 4004538  2023-05-07 10:19:00+00:00  28882.0  28868.5  28866.0  28882.0
# ...                            ...      ...      ...      ...      ...
# 4005552  2023-05-08 03:13:00+00:00  28328.5  28320.5  28320.5  28328.5
# 4005553  2023-05-08 03:14:00+00:00  28330.0  28329.5  28328.5  28330.0
# 4005554  2023-05-08 03:15:00+00:00  28329.5  28320.0  28330.0  28320.0
# 4005555  2023-05-08 03:16:00+00:00  28322.5  28289.5  28320.0  28304.0
# 4005556  2023-05-08 03:17:00+00:00  28314.0  28301.5  28304.0  28304.5
#
#          high_score
# 4004534           0
# 4004535           0
# 4004536           0
# 4004537           0
# ...

# %%
#5개짜리 밴드를 만들어 가장 큰 값을 기록하게 한다.
sample_y_df.iloc[0:5]
# Out:
#                          timestamp     high      low     open    close  \
# 4004534  2023-05-07 10:15:00+00:00  28866.5  28864.5  28866.5  28864.5
# 4004535  2023-05-07 10:16:00+00:00  28878.0  28855.5  28864.5  28870.5
# 4004536  2023-05-07 10:17:00+00:00  28880.5  28870.5  28870.5  28877.5
# 4004537  2023-05-07 10:18:00+00:00  28876.5  28865.5  28877.5  28866.0
# 4004538  2023-05-07 10:19:00+00:00  28882.0  28868.5  28866.0  28882.0
#
#          high_score
# 4004534           0
# 4004535           0
# 4004536           0
# 4004537           0
# 4004538           0

# %%
sample_y_df.iloc[0:5]['high'].max()
# Out:
# 28882.0

# %%
#가장 큰 값의 인덱스를 찾는 방법
max_row_index = sample_y_df.iloc[0:5]['high'].idxmax()

# %%
max_row_index
# Out:
# 4004538

# %%
sample_y_df.iloc[0:5].loc[max_row_index, 'high_score'] = sample_y_df.iloc[0:5].loc[max_row_index, 'high_score']+1

# %%
sample_y_df
sample_y_df.iloc[0:5]
# Out:
#                          timestamp     high      low     open    close  \
# 4004534  2023-05-07 10:15:00+00:00  28866.5  28864.5  28866.5  28864.5
# 4004535  2023-05-07 10:16:00+00:00  28878.0  28855.5  28864.5  28870.5
# 4004536  2023-05-07 10:17:00+00:00  28880.5  28870.5  28870.5  28877.5
# 4004537  2023-05-07 10:18:00+00:00  28876.5  28865.5  28877.5  28866.0
# 4004538  2023-05-07 10:19:00+00:00  28882.0  28868.5  28866.0  28882.0
#
#          high_score
# 4004534           0
# 4004535           0
# 4004536           0
# 4004537           0
# 4004538           1

# %%
len(sample_y_df)
# Out:
# 1000

# %%
sample_y_df.iloc[0:5]
# Out:
#                          timestamp     high      low     open    close  \
# 4004534  2023-05-07 10:15:00+00:00  28866.5  28864.5  28866.5  28864.5
# 4004535  2023-05-07 10:16:00+00:00  28878.0  28855.5  28864.5  28870.5
# 4004536  2023-05-07 10:17:00+00:00  28880.5  28870.5  28870.5  28877.5
# 4004537  2023-05-07 10:18:00+00:00  28876.5  28865.5  28877.5  28866.0
# 4004538  2023-05-07 10:19:00+00:00  28882.0  28868.5  28866.0  28882.0
#
#          high_score
# 4004534           0
# 4004535           0
# 4004536           0
# 4004537           0
# 4004538           1

# %%
sample_y_df.iloc[196:201]
# Out:
#                          timestamp     high      low     open    close  \
# 4004741  2023-05-07 13:42:00+00:00  29013.0  29002.0  28997.5  29013.0
# 4004742  2023-05-07 13:43:00+00:00  29014.0  29005.0  29013.0  29007.5
# 4004743  2023-05-07 13:44:00+00:00  29007.0  29001.0  29007.5  29001.0
# 4004744  2023-05-07 13:45:00+00:00  29000.5  29000.0  29001.0  29000.5
# 4004745  2023-05-07 13:46:00+00:00  29015.5  29000.5  29000.5  29015.5
#
#          high_score
# 4004741           0
# 4004742           0
# 4004743           0
# 4004744           0
# 4004745           0

# %%
#df를 제공하면서 밴드 값을 같이 제공하면 이를 반복문으로 돌아가면서 score 를 쌓는 함수
def get_high_score_with_bandwidth(target_df, column_name, bandwidth, reset=True):
    
    
    #일단 들어온 df 에 high_score 라는 컬럼 값 기본 강제 삽입
    if(reset==True):
        target_df['high_score']=0
    end_index = len(target_df) - bandwidth
    for idx,i in enumerate(range(end_index+1)):
        
        max_index = target_df.iloc[i:i+bandwidth][column_name].idxmax()
        
        #print(f"진입한 시작 값 : {i}~{i+bandwidth}")
        #print(f"가장 큰 인덱스 : {max_index}")
        #print(f"이때의 이미 기록된 값:{target_df.loc[max_index, 'high_score']} ")
        #print(f"이때의 이미 기록될 값:{target_df.loc[max_index]['high_score']+1} ")
        #print(max_index)
        
        #print(f"세팅전 값 : {target_df.loc[max_index]['high_score']}")
        
        #print(f"체크값 :{target_df.loc[max_row_index]['high_score']+1}")
        
        target_df.loc[max_index,'high_score'] = target_df.loc[max_index]['high_score']+1
        #print(f"세팅후 값 : {target_df.loc[max_index]['high_score']}")
        
    
    
    result_df = target_df.copy(deep=True)
    
    print(f"수행한 숫자:{end_index}")
    print(f"가장 높은 점수:{result_df.iloc[result_df['high_score'].idxmax()]}")
    
    return result_df

#df를 제공하면서 밴드 값을 같이 제공하면 이를 반복문으로 돌아가면서 score 를 쌓는 함수
def get_low_score_with_bandwidth(target_df, column_name, bandwidth, reset=True):
    
    
    #일단 들어온 df 에 high_score 라는 컬럼 값 기본 강제 삽입
    if(reset==True):
        target_df['low_score']=0
    end_index = len(target_df) - bandwidth
    for idx,i in enumerate(range(end_index+1)):
        
        min_index = target_df.iloc[i:i+bandwidth][column_name].idxmin()
        
        #print(f"진입한 시작 값 : {i}~{i+bandwidth}")
        #print(f"가장 큰 인덱스 : {max_index}")
        #print(f"이때의 이미 기록된 값:{target_df.loc[max_index, 'high_score']} ")
        #print(f"이때의 이미 기록될 값:{target_df.loc[max_index]['high_score']+1} ")
        #print(max_index)
        
        #print(f"세팅전 값 : {target_df.loc[max_index]['high_score']}")
        
        #print(f"체크값 :{target_df.loc[max_row_index]['high_score']+1}")
        
        target_df.loc[min_index,'low_score'] = target_df.loc[min_index]['low_score']+1
        #print(f"세팅후 값 : {target_df.loc[max_index]['high_score']}")
        
    
    
    result_df = target_df.copy(deep=True)
    return result_df

# %%
#new_df = get_high_score_with_bandwidth(sample_y_df, 'high', 5)
#print(len(new_df[new_df['high_score']!=0]))
#new_df = get_high_score_with_bandwidth(new_df, 'high', 10, reset=False)
#
#print(len(new_df[new_df['high_score']!=0]))
#new_df = get_high_score_with_bandwidth(new_df, 'high', 15, reset=False)
#print(len(new_df[new_df['high_score']!=0]))
#new_df = get_high_score_with_bandwidth(new_df, 'high', 20, reset=False)

# %%
#base_score = 30
#new_df_calculated=new_df.loc[new_df['high_score'] > base_score]
#new_df_calculated

# %% [markdown]
# new_df_calculated.loc[new_df_calculated['high_score'] > base_score, 'high_score'] = new_df_calculated['high']
#
# import numpy as np
# new_df_calculated.loc[new_df_calculated['high_score'] <= base_score, 'high_score'] = np.nan

# %%
#new_df_calculated[new_df_calculated['high_score']>1]

# %% [markdown]
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
#
# fig = make_subplots(rows=1, cols=2, subplot_titles=("첫 번째 그래프", "두 번째 그래프"))
#
# #fig = go.Figure()
#
# fig.add_trace(go.Scatter(y=list(new_df_calculated['high']), x=list(new_df_calculated['timestamp']), mode='lines', name='선형 그래프'), row=1, col=1)
#
# #fig.add_trace(go.Bar(y=list(new_df_calculated['high_score']), x=list(new_df_calculated['timestamp']), name='고점 그래프'), row=1, col=2)

# %%
#new_df

# %%
#fig = go.Figure(data=[])

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\User\\anaconda3\\envs\\es\\python.exe'

# %% [markdown]
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
#
# trace3 = go.Candlestick(
#     x=list(new_df['timestamp']),
#     open=list(new_df['open']),
#     high=list(new_df['high']),
#     low=list(new_df['low']),
#     close=list(new_df['close']),
# )
#
# trace1 = go.Scatter(y=list(new_df['high']), x=list(new_df['timestamp']), mode='lines', name='선형 그래프')
# trace2 = go.Scatter(y=list(new_df_calculated['high_score']), x=list(new_df_calculated['timestamp']), mode='markers', name='고점 그래프')
#
# fig = go.Figure(data=[trace3, trace2])
# fig.update_layout(
#     title='Candlestick Chart',
#     xaxis_title='Date',
#     yaxis_title='Price',
#     xaxis_rangeslider_visible=False,
#     width=1000,  # 그래프 너비 설정
#     height=800   # 그래프 높이 설정
# )
#
# fig.show()

# %%
def get_processed_df_from_raw(df,base_delta, from_date=None):
    if(from_date):
        df = df.loc[df.timestamp >= from_date]  #일단 GMT 니까 1분 뒤로 조정할 걸 생각하고 +1분부터 가져오면 된다.
    
    #kst 로 바꾸고 기존 gmt 형태는 drop
    df['timestamp_kst'] = df['timestamp'].apply(convert_gmt_to_kst)
    
    df = df[['timestamp_kst','open','low','high','close']]
    
    df = df.reset_index()
    
    #int 형태의 timestamp 열도 추가
    df['timestamp_int'] = df['timestamp_kst'].apply(convert_to_timestamp)
    
    #다시 필요한 컬럼만 정돈
    df = df[['timestamp_kst','timestamp_int','open', 'low','high','close']]
    
    #최종 x분봉의 형태구현 base_delta = 15, 45, 240, 1440
    final_df = df[['low']].rolling(window=base_delta).min()     
    final_df['open'] = df[['open']].rolling(window=base_delta).apply(lambda x: x[0], raw=True)
    final_df['high'] = df[['high']].rolling(window=base_delta).max() 
    final_df['close'] = df['close']                         
    final_df['timestamp_int'] = df[['timestamp_int']]-(base_delta*60-60)  
    
    final_df = final_df[base_delta-1:] #window수 -1 값만큼 버리고
    final_df['timestamp_kst'] = final_df['timestamp_int'].apply(convert_timestamp_to_datetime_str)
    final_df = final_df.reset_index()[['timestamp_kst','open','low','high','close','timestamp_int']] #리셋재구성
    
    return final_df[final_df['timestamp_int']%(base_delta*60)==0]

# %%
df.loc[df.timestamp >= '2022-12-31 15:01:00'][:16]
# Out:
#                          timestamp  symbol     open     high      low  \
# 3821940  2022-12-31 15:01:00+00:00  XBTUSD  16583.5  16584.0  16583.5
# 3821941  2022-12-31 15:02:00+00:00  XBTUSD  16584.0  16584.0  16583.5
# 3821942  2022-12-31 15:03:00+00:00  XBTUSD  16583.5  16584.0  16583.5
# 3821943  2022-12-31 15:04:00+00:00  XBTUSD  16584.0  16584.0  16584.0
# 3821944  2022-12-31 15:05:00+00:00  XBTUSD  16584.0  16584.0  16584.0
# 3821945  2022-12-31 15:06:00+00:00  XBTUSD  16584.0  16584.0  16584.0
# 3821946  2022-12-31 15:07:00+00:00  XBTUSD  16584.0  16584.0  16583.5
# 3821947  2022-12-31 15:08:00+00:00  XBTUSD  16583.5  16584.0  16584.0
# 3821948  2022-12-31 15:09:00+00:00  XBTUSD  16584.0  16584.0  16584.0
# 3821949  2022-12-31 15:10:00+00:00  XBTUSD  16584.0  16591.5  16584.0
# 3821950  2022-12-31 15:11:00+00:00  XBTUSD  16591.5  16597.0  16591.5
# 3821951  2022-12-31 15:12:00+00:00  XBTUSD  16594.5  16608.0  16591.5
# ...

# %%
#15분봉
df_15=get_processed_df_from_raw(df,15,'2022-12-31 15:01:00')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/1457726207.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp_kst'] = df['timestamp'].apply(convert_gmt_to_kst)

# %%
df_15
# Out:
#               timestamp_kst     open      low     high    close  timestamp_int
# 0       2023-01-01 00:00:00  16583.5  16583.5  16608.0  16600.0   1.672499e+09
# 15      2023-01-01 00:15:00  16600.0  16583.5  16607.0  16590.5   1.672500e+09
# 30      2023-01-01 00:30:00  16590.5  16582.5  16591.0  16586.0   1.672501e+09
# 45      2023-01-01 00:45:00  16586.0  16578.0  16586.5  16580.0   1.672502e+09
# 60      2023-01-01 01:00:00  16580.0  16579.5  16583.0  16583.0   1.672502e+09
# ...                     ...      ...      ...      ...      ...            ...
# 183540  2023-05-08 11:00:00  28308.0  28207.0  28374.0  28362.0   1.683511e+09
# 183555  2023-05-08 11:15:00  28362.0  28293.0  28374.0  28329.5   1.683512e+09
# 183570  2023-05-08 11:30:00  28329.5  28260.0  28330.5  28330.5   1.683513e+09
# 183585  2023-05-08 11:45:00  28330.5  28315.5  28395.0  28376.0   1.683514e+09
# 183600  2023-05-08 12:00:00  28376.0  28310.5  28377.5  28320.0   1.683515e+09
#
# ...

# %%
band_size_list = [200]


def get_high_score_by_list(origin_df,lst):
    if(len(lst)==0):
        print("대상이 없습니다.")
        
    else:
        return_df = None
        for idx, i in enumerate(lst):
            if(idx==0):
                return_df = get_high_score_with_bandwidth(origin_df, 'high', i)
            else:
                return_df = get_high_score_with_bandwidth(return_df, 'high', i, reset=False)
    
    return return_df

def get_low_score_by_list(origin_df,lst):
    if(len(lst)==0):
        print("대상이 없습니다.")
        
    else:
        return_df = None
        for idx, i in enumerate(lst):
            if(idx==0):
                return_df = get_low_score_with_bandwidth(origin_df, 'low', i)
            else:
                return_df = get_low_score_with_bandwidth(return_df, 'low', i, reset=False)
    
    return return_df
    


#15분봉으로 고점 찾기
new_df_15 = get_high_score_by_list(df_15,band_size_list)
new_df_15_low = get_low_score_by_list(df_15, band_size_list)

#new_df_15 = get_high_score_with_bandwidth(df_15, 'high', 5)
#new_df_15 = get_high_score_with_bandwidth(new_df_15, 'high', 10, reset=False)
#new_df_15 = get_high_score_with_bandwidth(new_df_15, 'high', 15, reset=False)
#new_df_15 = get_high_score_with_bandwidth(new_df_15, 'high', 20, reset=False)
#new_df_15 = get_high_score_with_bandwidth(new_df_15, 'high', 30, reset=False)
#new_df_15 = get_high_score_with_bandwidth(new_df_15, 'high', 40, reset=False)
# Out:
# 수행한 숫자:12041
# 가장 높은 점수:timestamp_kst    2023-04-04 03:00:00
# open                         27981.5
# low                          27959.0
# high                         28037.0
# close                        27978.5
# timestamp_int           1680544800.0
# high_score                         0
# Name: 134100, dtype: object

# %%
new_df_15
# Out:
#               timestamp_kst     open      low     high    close  \
# 0       2023-01-01 00:00:00  16583.5  16583.5  16608.0  16600.0
# 15      2023-01-01 00:15:00  16600.0  16583.5  16607.0  16590.5
# 30      2023-01-01 00:30:00  16590.5  16582.5  16591.0  16586.0
# 45      2023-01-01 00:45:00  16586.0  16578.0  16586.5  16580.0
# 60      2023-01-01 01:00:00  16580.0  16579.5  16583.0  16583.0
# ...                     ...      ...      ...      ...      ...
# 183540  2023-05-08 11:00:00  28308.0  28207.0  28374.0  28362.0
# 183555  2023-05-08 11:15:00  28362.0  28293.0  28374.0  28329.5
# 183570  2023-05-08 11:30:00  28329.5  28260.0  28330.5  28330.5
# 183585  2023-05-08 11:45:00  28330.5  28315.5  28395.0  28376.0
# 183600  2023-05-08 12:00:00  28376.0  28310.5  28377.5  28320.0
#
#         timestamp_int  high_score
# 0        1.672499e+09           0
# 15       1.672500e+09           0
# 30       1.672501e+09           0
# 45       1.672502e+09           0
# ...

# %%
#idxmax는 인덱스를 뽑고
#[:]요렇게 iloc 조회는 인덱스가 아닌 순서로 조회한다
new_df_15.iloc[new_df_15['high_score'].idxmax()]
# Out:
# timestamp_kst    2023-04-04 03:00:00
# open                         27981.5
# low                          27959.0
# high                         28037.0
# close                        27978.5
# timestamp_int           1680544800.0
# high_score                         0
# Name: 134100, dtype: object

# %%
#범위를 주면 인덱스로 뽑히고 하나만 찍으면 순서로 찍힌다.
new_df_15.loc[2475:2475]
# Out:
#             timestamp_kst     open      low     high    close  timestamp_int  \
# 2475  2023-01-02 17:15:00  16735.0  16713.0  16753.0  16715.0   1.672647e+09
#
#       high_score
# 2475          20

# %%
new_df_15.loc[new_df_15['high_score'].idxmax()]
# Out:
# timestamp_kst    2023-01-07 05:00:00
# open                         16926.5
# low                          16926.5
# high                         17050.0
# close                        16983.5
# timestamp_int           1673035200.0
# high_score                       200
# Name: 8940, dtype: object

# %%
#15분봉으로 저점 찾기

#new_df_15_low = get_low_score_with_bandwidth(df_15, 'low', 100)
#new_df_15_low = get_low_score_with_bandwidth(new_df_15_low, 'low', 10, reset=False)
##new_df_15_low = get_low_score_with_bandwidth(new_df_15_low, 'low', 15, reset=False)
#new_df_15_low = get_low_score_with_bandwidth(new_df_15_low, 'low', 20, reset=False)
#new_df_15_low = get_low_score_with_bandwidth(new_df_15_low, 'low', 30, reset=False)
#new_df_15_low = get_low_score_with_bandwidth(new_df_15_low, 'low', 40, reset=False)

# %%
new_df_15_low
# Out:
#               timestamp_kst     open      low     high    close  \
# 0       2023-01-01 00:00:00  16583.5  16583.5  16608.0  16600.0
# 15      2023-01-01 00:15:00  16600.0  16583.5  16607.0  16590.5
# 30      2023-01-01 00:30:00  16590.5  16582.5  16591.0  16586.0
# 45      2023-01-01 00:45:00  16586.0  16578.0  16586.5  16580.0
# 60      2023-01-01 01:00:00  16580.0  16579.5  16583.0  16583.0
# ...                     ...      ...      ...      ...      ...
# 183540  2023-05-08 11:00:00  28308.0  28207.0  28374.0  28362.0
# 183555  2023-05-08 11:15:00  28362.0  28293.0  28374.0  28329.5
# 183570  2023-05-08 11:30:00  28329.5  28260.0  28330.5  28330.5
# 183585  2023-05-08 11:45:00  28330.5  28315.5  28395.0  28376.0
# 183600  2023-05-08 12:00:00  28376.0  28310.5  28377.5  28320.0
#
#         timestamp_int  high_score  low_score
# 0        1.672499e+09           0          0
# 15       1.672500e+09           0          0
# 30       1.672501e+09           0          0
# ...

# %%
new_df_15_low.loc[new_df_15_low['low_score']>=119]
# Out:
#               timestamp_kst     open      low     high    close  \
# 4485    2023-01-04 02:45:00  16608.5  16596.0  16611.5  16611.5
# 8550    2023-01-06 22:30:00  16672.0  16665.5  16775.0  16759.5
# 26025   2023-01-19 01:45:00  20473.5  20398.0  20922.0  20844.5
# 32025   2023-01-23 05:45:00  22515.0  22265.0  22539.0  22459.5
# 35175   2023-01-25 10:15:00  22584.5  22333.5  22585.5  22364.5
# 38070   2023-01-27 10:30:00  22887.0  22525.0  22904.5  22672.0
# 43650   2023-01-31 07:30:00  22696.5  22368.5  22706.5  22699.5
# 46350   2023-02-02 04:30:00  22987.5  22690.5  23306.0  23269.5
# 48915   2023-02-03 23:15:00  23323.5  23178.0  23354.0  23304.5
# 52695   2023-02-06 14:15:00  22874.0  22624.0  22878.5  22705.0
# 59430   2023-02-11 06:30:00  21639.0  21450.0  21652.5  21518.5
# 63525   2023-02-14 02:45:00  21461.5  21351.0  21515.5  21469.5
# 72615   2023-02-20 10:15:00  23847.5  23840.5  24030.0  24012.5
# 76440   2023-02-23 02:00:00  23637.0  23569.5  23658.0  23587.5
# ...

# %%
#df와 타겟 컬럼명을 받아서 해당 %이상의 값만 필터링하는 함수
def apply_threshold_with_normalizing_for_high_value(target_df, target_column, threshold):

    #min-max 정규화
    target_df['normalized_value_high'] = (target_df[target_column] - target_df[target_column].min()) / (target_df[target_column].max() - target_df[target_column].min())
    
    threshold = target_df['normalized_value_high'].quantile(threshold)
    print(f"정형화된 기준값은 : {threshold}")
    
    #상위 5%에 포함되는 애들을 별도로 선언

    df_calculated = target_df[target_df['normalized_value_high'] >= threshold]
    df_calculated.loc[df_calculated['normalized_value_high'] >= threshold, 'origin_high_score'] = df_calculated[target_column]
    #그래프를 그리기 위한 수단을 벌써 넣으면 안됨
    df_calculated.loc[df_calculated['normalized_value_high'] >= threshold, 'high_for_graph'] = df_calculated['high']
    
    import numpy as np
    df_calculated.loc[df_calculated['normalized_value_high'] < threshold, target_column] = np.nan
    
    return df_calculated

def apply_threshold_with_normalizing_for_low_value(target_df, target_column, threshold):

    #min-max 정규화
    target_df['normalized_value_low'] = (target_df[target_column] - target_df[target_column].min()) / (target_df[target_column].max() - target_df[target_column].min())
    
    threshold = target_df['normalized_value_low'].quantile(threshold)
    print(f"정형화된 기준값은 : {threshold}")
    
    #threshold 로 적은 수 이하로 포함되는 애들을 별도로 선언

    df_calculated = target_df[target_df['normalized_value_low'] >= threshold]
    df_calculated.loc[df_calculated['normalized_value_low'] >= threshold, 'origin_low_score'] = df_calculated[target_column]
    #그래프를 그리기 위한 수단을 벌써 넣으면 안됨
    df_calculated.loc[df_calculated['normalized_value_low'] >= threshold, 'low_for_graph'] = df_calculated['low']
    
    import numpy as np
    df_calculated.loc[df_calculated['normalized_value_low'] < threshold, target_column] = np.nan
    
    return df_calculated


def merge_high_score_df(df_origin, base_score):
    df_calculated=df_origin.loc[df_origin['high_score'] > base_score]
    df_calculated.loc[df_calculated['high_score'] > base_score, 'origin_score'] = df_calculated['high_score']
    df_calculated.loc[df_calculated['high_score'] > base_score, 'high_score'] = df_calculated['high']

    import numpy as np
    df_calculated.loc[df_calculated['high_score'] <= base_score, 'high_score'] = np.nan
    
    return df_calculated

def merge_low_score_df(df_origin, base_score):
    df_calculated=df_origin.loc[df_origin['low_score'] > base_score]
    df_calculated.loc[df_calculated['low_score'] > base_score, 'origin_score'] = df_calculated['low_score']
    df_calculated.loc[df_calculated['low_score'] > base_score, 'low_score'] = df_calculated['low']

    import numpy as np
    df_calculated.loc[df_calculated['low_score'] <= base_score, 'low_score'] = np.nan
    
    return df_calculated

# %%
not_zero_high_df=new_df_15.loc[new_df_15['high_score']!=0]

# %%
not_zero_high_df
# Out:
#               timestamp_kst     open      low     high    close  \
# 2475    2023-01-02 17:15:00  16735.0  16713.0  16753.0  16715.0
# 3285    2023-01-03 06:45:00  16718.0  16718.0  16789.5  16740.5
# 5040    2023-01-04 12:00:00  16724.0  16723.0  16832.0  16828.0
# 5055    2023-01-04 12:15:00  16828.0  16787.5  16837.5  16793.0
# 5085    2023-01-04 12:45:00  16805.5  16805.5  16866.5  16857.0
# ...                     ...      ...      ...      ...      ...
# 180075  2023-05-06 01:15:00  29619.0  29540.0  29710.0  29545.5
# 180570  2023-05-06 09:30:00  29575.0  29572.5  29869.0  29733.5
# 180585  2023-05-06 09:45:00  29733.5  29685.5  29789.5  29710.5
# 180600  2023-05-06 10:00:00  29710.5  29602.5  29725.5  29650.0
# 180615  2023-05-06 10:15:00  29650.0  29559.0  29675.5  29601.0
#
#         timestamp_int  high_score
# 2475     1.672647e+09          20
# 3285     1.672696e+09         117
# 5040     1.672801e+09           1
# 5055     1.672802e+09           2
# ...

# %%
final_high_point=apply_threshold_with_normalizing_for_high_value(not_zero_high_df,'high_score',0.80)
final_high_point
# Out:
# 정형화된 기준값은 : 0.05527638190954774
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/105679151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_df['normalized_value_high'] = (target_df[target_column] - target_df[target_column].min()) / (target_df[target_column].max() - target_df[target_column].min())
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/105679151.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
not_zero_low_df=new_df_15_low.loc[new_df_15_low['low_score']!=0]
not_zero_low_df
# Out:
#               timestamp_kst     open      low     high    close  \
# 465     2023-01-01 07:45:00  16526.5  16424.5  16526.5  16502.5
# 480     2023-01-01 08:00:00  16502.5  16472.5  16504.0  16481.5
# 495     2023-01-01 08:15:00  16481.5  16481.5  16518.5  16511.5
# 975     2023-01-01 16:15:00  16506.0  16482.0  16506.5  16506.5
# 1095    2023-01-01 18:15:00  16490.0  16489.5  16500.5  16500.5
# ...                     ...      ...      ...      ...      ...
# 178470  2023-05-04 22:30:00  28887.0  28670.5  28941.5  28698.0
# 181380  2023-05-06 23:00:00  28975.5  28556.5  28973.5  28716.5
# 181440  2023-05-07 00:00:00  28639.0  28363.5  28638.5  28578.5
# 183510  2023-05-08 10:30:00  28528.0  28167.5  28652.5  28172.5
# 183525  2023-05-08 10:45:00  28172.5  28126.0  28308.5  28308.0
#
#         timestamp_int  high_score  low_score
# 465      1.672527e+09           0         32
# 480      1.672528e+09           0          1
# 495      1.672528e+09           0          1
# ...

# %%
final_low_point=apply_threshold_with_normalizing_for_low_value(not_zero_low_df,'low_score',0.80)
final_low_point
# Out:
# 정형화된 기준값은 : 0.06030150753768844
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/105679151.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_df['normalized_value_low'] = (target_df[target_column] - target_df[target_column].min()) / (target_df[target_column].max() - target_df[target_column].min())
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/105679151.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#new_df_15_calculated = merge_high_score_df(new_df_15,49)
#new_df_15_calculated_low = merge_low_score_df(new_df_15_low,119)

# %%
final_high_point
# Out:
#               timestamp_kst     open      low     high    close  \
# 2475    2023-01-02 17:15:00  16735.0  16713.0  16753.0  16715.0
# 3285    2023-01-03 06:45:00  16718.0  16718.0  16789.5  16740.5
# 5100    2023-01-04 13:00:00  16857.0  16855.5  16904.0  16856.0
# 5355    2023-01-04 17:15:00  16888.0  16849.5  16915.0  16849.5
# 6000    2023-01-05 04:00:00  16950.5  16861.0  16978.0  16870.0
# ...                     ...      ...      ...      ...      ...
# 177555  2023-05-04 07:15:00  29037.5  29038.0  29278.5  29182.0
# 178290  2023-05-04 19:30:00  29180.5  29171.5  29400.0  29294.5
# 179220  2023-05-05 11:00:00  29330.0  29250.0  29549.5  29279.0
# 180075  2023-05-06 01:15:00  29619.0  29540.0  29710.0  29545.5
# 180570  2023-05-06 09:30:00  29575.0  29572.5  29869.0  29733.5
#
#         timestamp_int  high_score  normalized_value_high  origin_high_score  \
# 2475     1.672647e+09        20.0               0.095477                 20
# ...

# %%
def draw_base(trace_list):
    import plotly.graph_objects as go
    
    layout = go.Layout(
    width=1000,  # 가로 크기
    height=800  # 세로 크기
    )
    fig = go.Figure(data=trace_list)
    
    fig.update_layout(
    title='Candlestick Chart',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False,
    width=1000,  # 그래프 너비 설정
    height=800   # 그래프 높이 설정
    )
    
    fig.show()

def draw_candlechart(df):
    import plotly.graph_objects as go
    
    main_trace = go.Candlestick(
    x=list(df['timestamp_kst']),
    open=list(df['open']),
    high=list(df['high']),
    low=list(df['low']),
    close=list(df['close']),
    )
        
    fig = go.Figure(data=[main_trace])
    fig.update_layout(
    title='Candlestick Chart',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False,
    width=1000,  # 그래프 너비 설정
    height=800   # 그래프 높이 설정
    )
    
    fig.show()

# %%
#15분봉 그려보기
#draw_candlechart(df_15)

#메인트레이스 만들기
import plotly.graph_objects as go

main_trace = go.Candlestick(
    x=list(df_15['timestamp_kst']),
    open=list(df_15['open']),
    high=list(df_15['high']),
    low=list(df_15['low']),
    close=list(df_15['close']),
    )

#두번째 고가 점 트레이스 만들기
high_point_trace = go.Scatter(y=list(final_high_point['high_for_graph']), x=list(final_high_point['timestamp_kst']), 
        marker=dict(
        color='rgba(255, 0, 255, 1)',  # 점의 색상 설정 (RGBa 형식)
        size=5,  # 점의 크기 설정
    ),
    mode='markers', name='고점 그래프')

#세번째 저가 점 트레이스 만들기
low_point_trace = go.Scatter(y=list(final_low_point['low_for_graph']), x=list(final_low_point['timestamp_kst']), 
        marker=dict(
        color='rgba(0, 0, 0, 1)',  # 점의 색상 설정 (RGBa 형식)
        size=5,  # 점의 크기 설정
    ),
                             mode='markers', name='저점 그래프')

# %%
#그리기
draw_base([main_trace,high_point_trace,low_point_trace])
# Out:
# <div>                            <div id="35064909-b75a-4c4c-9c09-6a210bb458fd" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35064909-b75a-4c4c-9c09-6a210bb458fd")) {                    Plotly.newPlot(                        "35064909-b75a-4c4c-9c09-6a210bb458fd",                        [{"close":[16600.0,16590.5,16586.0,16580.0,16583.0,16588.5,16586.0,16592.5,16578.0,16568.5,16568.5,16568.5,16568.5,16565.5,16563.5,16563.0,16562.5,16557.5,16559.5,16556.0,16553.5,16553.0,16553.5,16551.5,16552.0,16551.5,16547.0,16540.0,16553.5,16535.5,16526.5,16502.5,16481.5,16511.5,16529.5,16522.0,16509.0,16524.0,16503.0,16522.5,16524.5,16524.0,16525.0,16539.0,16534.0,16534.5,16529.0,16529.5,16512.0,16512.5,16512.5,16513.0,16509.0,16501.0,16501.0,16501.0,16501.5
# ...

# %%
#이전 값보다 높으면 True찍기
final_high_point['increasing'] = final_high_point['high_for_graph'] > final_high_point['high_for_graph'].shift()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/2036170384.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#True 가 4개 이상 유지되는 구간을 그래프에 표시해보기

# %%
final_high_point[100:138]
# Out:
#               timestamp_kst     open      low     high    close  \
# 136665  2023-04-05 21:45:00  28473.0  28444.5  28748.5  28570.5
# 137085  2023-04-06 04:45:00  28301.5  28231.0  28308.5  28237.0
# 138270  2023-04-07 00:30:00  28068.5  28047.5  28183.5  28134.5
# 140580  2023-04-08 15:00:00  28154.0  28112.0  28170.5  28122.0
# 142980  2023-04-10 07:00:00  28445.0  28404.0  28538.5  28412.0
# 144120  2023-04-11 02:00:00  29064.5  29042.0  29362.0  29162.0
# 144660  2023-04-11 11:00:00  30235.0  30144.0  30474.0  30299.0
# 145695  2023-04-12 04:15:00  30278.5  30285.0  30580.0  30458.0
# 148320  2023-04-14 00:00:00  30475.0  30330.0  30637.0  30361.5
# 148965  2023-04-14 10:45:00  30844.5  30780.0  30953.5  30802.5
# 149265  2023-04-14 15:45:00  30860.5  30859.5  31059.0  30967.5
# 149610  2023-04-14 21:30:00  30834.5  30757.5  30876.0  30770.0
# 150315  2023-04-15 09:15:00  30449.5  30433.5  30599.5  30556.0
# 152880  2023-04-17 04:00:00  30496.0  30446.0  30584.0  30523.0
# ...

# %%
import numpy as np
import pandas as pd

# 예제 데이터
data = list(final_high_point['high_for_graph'])

# 1. 증가 여부를 계산
# 각 요소가 이전 요소보다 큰지 비교
increasing = [data[i] < data[i+1] for i in range(len(data) - 1)]
increasing.append(False)  # 마지막 요소는 비교 대상 없음

# 2. 연속적으로 3번 증가하는 구간 찾기
streak_length = 7
result_indices = []
for i in range(len(increasing) - (streak_length - 1)):
    # 연속 증가 조건 확인
    if all(increasing[i:i+streak_length-1]):
        result_indices.append(i)

# 3. 결과 출력
result = [data[i:i+streak_length] for i in result_indices]

print("연속 증가 구간 인덱스:", result_indices)
print("연속 증가 구간 값:", result)
# Out:
# 연속 증가 구간 인덱스: [0, 1, 2, 3, 4, 5, 6, 7, 8, 42, 103, 104]
# 연속 증가 구간 값: [[16753.0, 16789.5, 16904.0, 16915.0, 16978.0, 17050.0, 17254.5], [16789.5, 16904.0, 16915.0, 16978.0, 17050.0, 17254.5, 17306.5], [16904.0, 16915.0, 16978.0, 17050.0, 17254.5, 17306.5, 17392.0], [16915.0, 16978.0, 17050.0, 17254.5, 17306.5, 17392.0, 17485.5], [16978.0, 17050.0, 17254.5, 17306.5, 17392.0, 17485.5, 17500.5], [17050.0, 17254.5, 17306.5, 17392.0, 17485.5, 17500.5, 18355.0], [17254.5, 17306.5, 17392.0, 17485.5, 17500.5, 18355.0, 18400.0], [17306.5, 17392.0, 17485.5, 17500.5, 18355.0, 18400.0, 19111.5], [17392.0, 17485.5, 17500.5, 18355.0, 18400.0, 19111.5, 21550.0], [21914.5, 21967.0, 22086.0, 22320.0, 22928.0, 24928.5, 25296.0], [28170.5, 28538.5, 29362.0, 30474.0, 30580.0, 30637.0, 30953.5], [28538.5, 29362.0, 30474.0, 30580.0, 30637.0, 30953.5, 31059.0]]

# %%
#높은 지점 중에 상방 플래그 패턴인 구간을 찾아보기

final_high_point['high_for_graph']
# Out:
# 2475      16753.0
# 3285      16789.5
# 5100      16904.0
# 5355      16915.0
# 6000      16978.0
#            ...
# 177555    29278.5
# 178290    29400.0
# 179220    29549.5
# 180075    29710.0
# 180570    29869.0
# Name: high_for_graph, Length: 138, dtype: float64

# %%
#45분봉
df_45=get_processed_df_from_raw(df,45,'2022-12-31 15:01:00')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/1457726207.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_15.loc[45]
# Out:
# timestamp_kst    2023-01-01 00:45:00
# open                         16586.0
# low                          16578.0
# high                         16586.5
# close                        16580.0
# timestamp_int           1672501500.0
# high_score                         0
# low_score                          0
# Name: 45, dtype: object

# %%
df_45.loc[45]
# Out:
# timestamp_kst    2023-01-01 00:45:00
# open                         16586.0
# low                          16573.5
# high                         16588.5
# close                        16588.5
# timestamp_int           1672501500.0
# Name: 45, dtype: object

# %%
draw_candlechart(df_45)
# Out:
# <div>                            <div id="7631fc33-fa19-42df-b275-c3adb1740412" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7631fc33-fa19-42df-b275-c3adb1740412")) {                    Plotly.newPlot(                        "7631fc33-fa19-42df-b275-c3adb1740412",                        [{"close":[16586.0,16588.5,16578.0,16568.5,16563.5,16557.5,16553.5,16551.5,16547.0,16535.5,16481.5,16522.0,16503.0,16524.0,16534.0,16529.5,16512.5,16501.0,16501.5,16519.0,16527.5,16506.5,16503.0,16496.0,16514.5,16524.5,16528.0,16530.5,16543.5,16533.0,16534.0,16532.5,16529.5,16569.0,16558.0,16575.5,16586.5,16614.5,16596.5,16595.5,16597.5,16593.0,16618.0,16610.0,16583.5,16554.5,16563.0,16578.5,16600.5,16636.5,16623.5,16640.0,16628.0,16716.5,16735.0,16715.0,16705.0
# ...

# %%
#4시간봉
get_processed_df_from_raw(df,240,'2022-12-31 15:01:00')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/1457726207.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               timestamp_kst     open      low     high    close  timestamp_int
# 60      2023-01-01 01:00:00  16580.0  16555.5  16596.5  16556.0   1.672502e+09
# 300     2023-01-01 05:00:00  16556.0  16424.5  16555.5  16522.0   1.672517e+09
# 540     2023-01-01 09:00:00  16522.0  16494.5  16540.0  16513.0   1.672531e+09
# 780     2023-01-01 13:00:00  16513.0  16482.0  16528.5  16517.5   1.672546e+09
# 1020    2023-01-01 17:00:00  16517.5  16489.5  16530.5  16530.5   1.672560e+09
# ...                     ...      ...      ...      ...      ...            ...
# ...

# %%
#일봉
df_day=get_processed_df_from_raw(df,1440,'2022-12-31 15:01:00')
df_day
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/1457726207.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               timestamp_kst     open      low     high    close  timestamp_int
# 540     2023-01-01 09:00:00  16522.0  16482.0  16618.0  16610.0   1.672531e+09
# 1980    2023-01-02 09:00:00  16610.0  16544.5  16789.5  16670.0   1.672618e+09
# 3420    2023-01-03 09:00:00  16670.0  16596.0  16765.0  16656.0   1.672704e+09
# 4860    2023-01-04 09:00:00  16656.0  16639.5  16978.0  16842.5   1.672790e+09
# 6300    2023-01-05 09:00:00  16842.5  16750.5  16872.0  16818.0   1.672877e+09
# ...                     ...      ...      ...      ...      ...            ...
# ...

# %%
draw_candlechart(df_day)
# Out:
# <div>                            <div id="02f747c2-ff94-4e0c-8ab6-36bf6b1574ed" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02f747c2-ff94-4e0c-8ab6-36bf6b1574ed")) {                    Plotly.newPlot(                        "02f747c2-ff94-4e0c-8ab6-36bf6b1574ed",                        [{"close":[16610.0,16670.0,16656.0,16842.5,16818.0,16947.0,16940.0,17131.0,17167.5,17442.5,17943.0,18837.5,19920.0,20948.0,20879.0,21186.0,21118.5,20671.0,21063.5,22665.0,22778.5,22697.5,22910.5,22629.5,23055.0,23004.0,23068.0,23020.5,23743.5,22807.5,23112.0,23734.0,23487.0,23424.0,23298.0,22933.0,22756.0,23230.5,22954.5,21794.0,21620.0,21846.5,21780.0,21769.5,22190.0,24352.0,23512.5,24585.5,24638.5,24272.0,24855.0,24456.5,24178.0,23943.0,23176.5,23154.5,23548.5
# ...

# %%
#주봉은 월요일 기준으로 맞추는게 일반적인데 최근 데이터의 일자로 맞추어져서 기준일이 안맞음.. 별도로 처리 필요
get_processed_df_from_raw(df,10080,'2022-12-31 15:01:00')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_21204/1457726207.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               timestamp_kst     open      low     high    close  timestamp_int
# 6300    2023-01-05 09:00:00  16842.5  16665.5  18000.0  17943.0   1.672877e+09
# 16380   2023-01-12 09:00:00  17943.0  17909.5  21652.5  20671.0   1.673482e+09
# 26460   2023-01-19 09:00:00  20671.0  20650.5  23903.0  23055.0   1.674086e+09
# 36540   2023-01-26 09:00:00  23055.0  22368.5  23970.5  23734.0   1.674691e+09
# 46620   2023-02-02 09:00:00  23734.0  22624.0  24264.0  22954.5   1.675296e+09
# 56700   2023-02-09 09:00:00  22954.5  21351.0  24393.0  24352.0   1.675901e+09
# ...

# %% [markdown]
# import pandas as pd
# import plotly.graph_objects as go
#
# # 예시 데이터프레임 생성
# data = {
#     'date': pd.date_range(start='2022-01-01', periods=10, freq='D'),
#     'open': [100, 102, 104, 103, 105, 107, 106, 108, 110, 111],
#     'high': [105, 107, 108, 109, 110, 111, 113, 114, 115, 116],
#     'low': [95, 99, 100, 101, 102, 103, 104, 105, 106, 107],
#     'close': [102, 104, 103, 105, 107, 106, 108, 110, 111, 113]
# }
#
# df = pd.DataFrame(data)
#
# # 캔들 차트 그리기
# fig = go.Figure(data=[go.Candlestick(
#     x=df['date'],
#     open=df['open'],
#     high=df['high'],
#     low=df['low'],
#     close=df['close']
# )])
#
# # 차트 레이아웃 설정
# fig.update_layout(
#     title='Candlestick Chart',
#     xaxis_title='Date',
#     yaxis_title='Price',
#     xaxis_rangeslider_visible=False
# )
#
# # 차트 출력
# fig.show()

# %%
new_df_15.loc[new_df_15['high_score']!=0]['high_score']
# Out:
# 2475       20
# 3285      117
# 5040        1
# 5055        2
# 5085        1
#          ...
# 180075     33
# 180570    200
# 180585      1
# 180600      1
# 180615      1
# Name: high_score, Length: 685, dtype: int64

# %%
new_df_15.loc[new_df_15['high_score']!=0]['high_score'].mean()
# Out:
# 17.57956204379562

# %%
apply_threshold_with_normalizing(new_df_15, 'high_score',0.95)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21204/540289477.py in <module>
# ----> 1 apply_threshold_with_normalizing(new_df_15, 'high_score',0.95)
#
# NameError: name 'apply_threshold_with_normalizing' is not defined

# %%
not_0_high_score_df = new_df_15.loc[new_df_15['high_score']!=0]

# %%
not_0_high_score_df['high_score']

# %%
# 정규화: 값 범위를 0에서 1 사이로 변환
not_0_high_score_df['normalized_high_score']=(not_0_high_score_df['high_score'] - not_0_high_score_df['high_score'].min()) / (not_0_high_score_df['high_score'].max() - not_0_high_score_df['high_score'].min())

# %%
not_0_high_score_df

# %%
threshold = not_0_high_score_df['normalized_high_score'].quantile(0.95)
threshold

# %%
top_5_percent_normalized = not_0_high_score_df[not_0_high_score_df['normalized_high_score'] >= threshold]

# %%
top_5_percent_normalized

# %%
increasing = [data[i] < data[i+1] for i in range(len(data) - 1)]
increasing
