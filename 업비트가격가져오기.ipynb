# %%
import sys
# !{sys.executable} -m pip install pyupbit
# Out:
# ...
#                                               0.0/176.8 kB ? eta -:--:--
#      ------------------------------------- 176.8/176.8 kB 10.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: d:\python3.9.5\python.exe -m pip install --upgrade pip

# %%
import pyupbit

print(pyupbit.Upbit)
# Out:
# <class 'pyupbit.exchange_api.Upbit'>

# %%
import pyupbit

tickers = pyupbit.get_tickers()

# %%
tickers
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'BTC-ETH',
#  'BTC-XRP',
#  'BTC-ETC',
#  'BTC-CVC',
#  'BTC-DGB',
#  'BTC-SC',
#  'BTC-SNT',
#  'BTC-WAVES',
#  'BTC-NMR',
#  'BTC-XEM',
#  'BTC-QTUM',
#  'BTC-BAT',
#  'BTC-LSK',
#  'BTC-STEEM',
#  'BTC-DOGE',
#  'BTC-BNT',
#  'BTC-XLM',
#  'BTC-ARDR',
#  'BTC-ARK',
#  'BTC-STORJ',
#  'BTC-GRS',
#  'BTC-RLC',
#  'USDT-BTC',
#  'USDT-ETH',
#  'USDT-XRP',
#  'USDT-ETC',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-ADA',
#  'BTC-ADA',
#  'BTC-MANA',
#  'KRW-POWR',
#  'BTC-POWR',
#  'USDT-ADA',
#  'BTC-DNT',
#  'BTC-ZRX',
#  'BTC-TRX',
#  'BTC-TUSD',
#  'BTC-LRC',
#  'KRW-ICX',
#  'KRW-EOS',
#  'USDT-TUSD',
#  'KRW-TRX',
#  'BTC-POLYX',
#  'USDT-SC',
#  'USDT-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLYX',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'BTC-BCH',
#  'USDT-BCH',
# ...

# %%
import pyupbit

tickers = pyupbit.get_tickers('KRW')

print(tickers)
# Out:
# ['KRW-BTC', 'KRW-ETH', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-ETC', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-ADA', 'KRW-POWR', 'KRW-ICX', 'KRW-EOS', 'KRW-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLYX', 'KRW-ZRX', 'KRW-LOOM', 'KRW-BCH', 'KRW-BAT', 'KRW-IOST', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'KRW-HIFI', 'KRW-ONG', 'KRW-GAS', 'KRW-BOUNTY', 'KRW-ELF', 'KRW-KNC', 'KRW-BSV', 'KRW-THETA', 'KRW-QKC', 'KRW-BTT', 'KRW-MOC', 'KRW-TFUEL', 'KRW-MANA', 'KRW-ANKR', 'KRW-AERGO', 'KRW-ATOM', 'KRW-TT', 'KRW-GAME2', 'KRW-MBL', 'KRW-WAXP', 'KRW-HBAR', 'KRW-MED', 'KRW-MLK', 'KRW-STPT', 'KRW-ORBS', 'KRW-VET', 'KRW-CHZ', 'KRW-STMX', 'KRW-DKA', 'KRW-HIVE', 'KRW-KAVA', 'KRW-AHT', 'KRW-LINK', 'KRW-XTZ', 'KRW-BORA', 'KRW-JST', 'KRW-CRO', 'KRW-TOKAMAK', 'KRW-SXP', 'KRW-HUNT', 'KRW-DOT', 'KRW-MVL', 'KRW-STRAX', 'KRW-AQT', 'KRW-GLM', 'KRW-META', 'KRW-FCT2', 'KRW-CBK', 'KRW-SAND', 'KRW-HPO', 'KRW-DOGE', 'KRW-STRIKE', 'K
# ...

# %%
import pyupbit

BTC = pyupbit.get_current_price('KRW-BTC')

print(BTC)

# %%
import pyupbit

df = pyupbit.get_ohlcv('KRW-AUCTION')

# %%
df
# Out:
#                         open     high      low    close        volume  \
# 2024-08-31 09:00:00  20720.0  20780.0  19850.0  20060.0  1.976602e+05
# 2024-09-01 09:00:00  20060.0  20060.0  18670.0  18770.0  3.159026e+05
# 2024-09-02 09:00:00  18780.0  19480.0  18570.0  19270.0  2.554795e+05
# 2024-09-03 09:00:00  19280.0  19570.0  17800.0  18000.0  3.229923e+05
# 2024-09-04 09:00:00  18000.0  18290.0  17050.0  17960.0  3.048905e+05
# ...                      ...      ...      ...      ...           ...
# 2025-03-14 09:00:00  38140.0  43410.0  36470.0  40850.0  2.948469e+06
# 2025-03-15 09:00:00  40850.0  40850.0  37010.0  38690.0  1.933403e+06
# 2025-03-16 09:00:00  38630.0  53600.0  37730.0  51250.0  1.060289e+07
# 2025-03-17 09:00:00  51280.0  54630.0  45300.0  47370.0  5.028933e+06
# 2025-03-18 09:00:00  47360.0  49190.0  43530.0  47370.0  2.849300e+06
#
#                             value
# 2024-08-31 09:00:00  4.003455e+09
# 2024-09-01 09:00:00  6.088853e+09
# ...

# %%
df = pyupbit.get_ohlcv('KRW-AUCTION', interval="minute60", count=2000)

# %%
df
# Out:
#                         open     high      low    close         volume  \
# 2024-12-25 10:00:00  32400.0  33400.0  32400.0  32820.0   80732.789146
# 2024-12-25 11:00:00  32910.0  34380.0  32450.0  34250.0  172612.621568
# 2024-12-25 12:00:00  34180.0  34450.0  33020.0  33540.0  177994.440508
# 2024-12-25 13:00:00  33540.0  37870.0  33540.0  36320.0  615396.357220
# 2024-12-25 14:00:00  36410.0  38890.0  34350.0  36050.0  592132.319337
# ...                      ...      ...      ...      ...            ...
# 2025-03-18 18:00:00  45040.0  46750.0  44650.0  45940.0  141759.624353
# 2025-03-18 19:00:00  45950.0  47760.0  45600.0  46980.0  274201.727791
# 2025-03-18 20:00:00  46980.0  48090.0  46450.0  47080.0  194789.937568
# 2025-03-18 21:00:00  47080.0  49190.0  45830.0  48510.0  408561.221152
# 2025-03-18 22:00:00  48540.0  48640.0  47100.0  47490.0  136175.694742
#
#                             value
# 2024-12-25 10:00:00  2.662260e+09
# 2024-12-25 11:00:00  5.753989e+09
# ...

# %%
df.reset_index()
# Out:
#                    index     open     high      low    close         volume  \
# 0    2024-12-25 10:00:00  32400.0  33400.0  32400.0  32820.0   80732.789146
# 1    2024-12-25 11:00:00  32910.0  34380.0  32450.0  34250.0  172612.621568
# 2    2024-12-25 12:00:00  34180.0  34450.0  33020.0  33540.0  177994.440508
# 3    2024-12-25 13:00:00  33540.0  37870.0  33540.0  36320.0  615396.357220
# 4    2024-12-25 14:00:00  36410.0  38890.0  34350.0  36050.0  592132.319337
# ...                  ...      ...      ...      ...      ...            ...
# 1995 2025-03-18 18:00:00  45040.0  46750.0  44650.0  45940.0  141759.624353
# 1996 2025-03-18 19:00:00  45950.0  47760.0  45600.0  46980.0  274201.727791
# 1997 2025-03-18 20:00:00  46980.0  48090.0  46450.0  47080.0  194789.937568
# 1998 2025-03-18 21:00:00  47080.0  49190.0  45830.0  48510.0  408561.221152
# 1999 2025-03-18 22:00:00  48540.0  48640.0  47100.0  47490.0  136175.694742
#
#              value
# 0     2.662260e+09
# ...

# %%
import os,sys
print(os.getcwd())

# %%
import os
print(os.environ.get('CONDA_PREFIX'))
